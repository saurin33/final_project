# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user pandas==1.0.3
# Out:
# ...
#      |████████████████████████████████| 10.0MB 6.7MB/s eta 0:00:01
# ...
# ERROR: pyportfolioopt 1.1.0 has requirement pandas<0.26.0,>=0.25.3, but you'll have pandas 1.0.3 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update pandas
# Out:
# ...
# Solving environment: \
#
# Updating pandas is constricted by
#
# anaconda -> requires pandas==0.25.1=py37h0a44026_0
#
# If you are sure you want an update of your package either try `conda update --all` or install a specific version of the package you want using `conda install <pkg>=<version>`
#
# done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     backports.functools_lru_cache-1.6.1|             py_0          11 KB
#     conda-package-handling-1.6.1|   py37h1de35cc_0         1.3 MB
#     future-0.18.2              |           py37_0         638 KB
#     ------------------------------------------------------------
#                                            Total:         1.9 MB
#
# The following packages will be UPDATED:
#
# ...

# %%
import pandas as pd

# %%
import pandas as pd
from pymongo import MongoClient
client = MongoClient('home.unheard.org', 27017, username='paperstraws', password='paperstraws', authSource='beerisawesome', authMechanism='SCRAM-SHA-256')
db = client['beerisawesome']
collection_ratebeer = db['brewerydb']
#results = collection_ratebeer.find({"style.shortName":"American Pale"})
#results
for result in collection_brewerydb.find({}):
    print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-0aeefbcc9730> in <module>
#       6 #results = collection_ratebeer.find({"style.shortName":"American Pale"})
#       7 #results
# ----> 8 for result in collection_brewerydb.find({}):
#       9     print(result)
#
# NameError: name 'collection_brewerydb' is not defined

# %%
client = MongoClient('home.unheard.org', 27017, username='paperstraws', password='paperstraws', authSource='beerisawesome', authMechanism='SCRAM-SHA-256')
db = client['beerisawesome']
collection_brewerydb = db['brewerydb']
x_1 = collection_brewerydb.find({})
x_1 = pd.DataFrame(x)

# %%
x_1
# Out:
#                             _id      id                             name  \
# 0      5ec52088924fb906c61619ff  sriHKq                     Main Brewery
# 1      5ec52088924fb906c6161a00  y2ng8G                     Main Brewery
# 2      5ec52088924fb906c6161a01  cLqv0i                     Main Brewery
# 3      5ec52088924fb906c6161a02  pmrzyC                     Main Brewery
# 4      5ec52088924fb906c6161a03  U5vEqe                     Main Brewery
# ...                         ...     ...                              ...
# 13261  5ec52185924fb906c61645fe  KCqYKy          Zymurcracy Beer Company
# 13262  5ec52185924fb906c61645ff  wWZMUP  [the pub] by iron horse brewery
# 13263  5ec52185924fb906c6164600  2V2RQA                          Æblerov
# 13264  5ec52185924fb906c6164601  VtK9UN                      Ølsnedkeren
# 13265  5ec52185924fb906c6164602  q2cWOY                         афанасий
#
#                  streetAddress          locality          region postalCode  \
# ...

# %%
for result in collection_ratebeer.find({"style.shortName":"American Pale"},{"_id":0,"name":1}):
    print(result)

# %%
for result in collection_ratebeer.find({"style.shortName":"American Pale"},{"_id":0,"name":1, "style.name":1}):
    print(result)

# %%
for result in collection_ratebeer.find({"style.shortName":"American Pale"},{"_id":0,"name":1, "abv":1, "ibu":1}):
    print(result)

# %%
for result in collection_ratebeer.find({},{"_id":0,"name":1, "abv":1, "ibu":1}):
    print(result)
# Out:
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# {'name': 'Main Brewery'}
# ...

# %%
x = pd.DataFrame(list(collection_.find({})))

# %%
x
# Out:
#                             _id      id                             name  \
# 0      5ec52088924fb906c61619ff  sriHKq                     Main Brewery
# 1      5ec52088924fb906c6161a00  y2ng8G                     Main Brewery
# 2      5ec52088924fb906c6161a01  cLqv0i                     Main Brewery
# 3      5ec52088924fb906c6161a02  pmrzyC                     Main Brewery
# 4      5ec52088924fb906c6161a03  U5vEqe                     Main Brewery
# ...                         ...     ...                              ...
# 13261  5ec52185924fb906c61645fe  KCqYKy          Zymurcracy Beer Company
# 13262  5ec52185924fb906c61645ff  wWZMUP  [the pub] by iron horse brewery
# 13263  5ec52185924fb906c6164600  2V2RQA                          Æblerov
# 13264  5ec52185924fb906c6164601  VtK9UN                      Ølsnedkeren
# 13265  5ec52185924fb906c6164602  q2cWOY                         афанасий
#
#                  streetAddress          locality          region postalCode  \
# ...

# %%
x = pd.DataFrame(pd.json_normalize(list(collection_ratebeer.find({},{"_id":0,"name":1,"style.name":1,"abv":1,"ibu":1}))))

# %%
x
# Out:
#                                   name
# 0                         Main Brewery
# 1                         Main Brewery
# 2                         Main Brewery
# 3                         Main Brewery
# 4                         Main Brewery
# ...                                ...
# 13261          Zymurcracy Beer Company
# 13262  [the pub] by iron horse brewery
# 13263                          Æblerov
# 13264                      Ølsnedkeren
# 13265                         афанасий
#
# [13266 rows x 1 columns]
